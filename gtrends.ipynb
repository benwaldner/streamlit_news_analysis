# %%
# !pip install pytrends
# Out:
# Requirement already satisfied: pytrends in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (4.9.2)
# Requirement already satisfied: requests>=2.0 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from pytrends) (2.32.3)
# Requirement already satisfied: pandas>=0.25 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from pytrends) (2.2.2)
# Requirement already satisfied: lxml in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from pytrends) (5.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.25->pytrends) (2.0.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.25->pytrends) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.25->pytrends) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from pandas>=0.25->pytrends) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pytrends) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pytrends) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pytrends) (2.2.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0->pytrends) (2024.7.4)
# Requirement already satisfied: six>=1.5 in c:\users\beni.waldner\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends) (1.16.0)

# %%
from pytrends.request import TrendReq
import pandas as pd
import matplotlib.pyplot as plt

# %%
'''
# Initialize pytrends
pytrends = TrendReq()

# Function to get Google Trends data
def get_trends_data(keyword, timeframe):
    pytrends.build_payload(kw_list=[keyword], timeframe=timeframe)
    data = pytrends.interest_over_time()
    return data

# Fetch data
keyword = 'bitcoin'  # You can change this keyword
#timeframe = 'today 7-d'  # You can change this timeframe
timeframe = "2024-01-03 2024-08-03"
data = get_trends_data(keyword, timeframe)
'''
# Out:
# '\n# Initialize pytrends\npytrends = TrendReq()\n\n# Function to get Google Trends data\ndef get_trends_data(keyword, timeframe):\n    pytrends.build_payload(kw_list=[keyword], timeframe=timeframe)\n    data = pytrends.interest_over_time()\n    return data\n\n# Fetch data\nkeyword = \'bitcoin\'  # You can change this keyword\n#timeframe = \'today 7-d\'  # You can change this timeframe\ntimeframe = "2024-01-03 2024-08-03"\ndata = get_trends_data(keyword, timeframe)\n'

# %%
# Initialize pytrends
pytrends = TrendReq()

# Function to get Google Trends data
def get_trends_data(keyword, timeframe):
    pytrends.build_payload(kw_list=[keyword], timeframe=timeframe)
    data = pytrends.interest_over_time()
    return data

# Fetch data
keyword = 'bitcoin'  # You can change this keyword
#timeframe = 'today 7-d'  # You can change this timeframe
timeframe = "2024-01-03 2024-08-03"
data = get_trends_data(keyword, timeframe)
pd.set_option('future.no_silent_downcasting', True)

# %%
# Display the data
data.head()
# Out:
#             bitcoin  isPartial
# date
# 2024-01-03       52      False
# 2024-01-04       43      False
# 2024-01-05       40      False
# 2024-01-06       35      False
# 2024-01-07       35      False

# %%
data.tail()
# Out:
#             bitcoin  isPartial
# date
# 2024-07-30       30      False
# 2024-07-31       28      False
# 2024-08-01       29      False
# 2024-08-02       30      False
# 2024-08-03       28       True

# %%
# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(data.index, data[keyword], label=f'Interest Over Time for "{keyword}"')
plt.xlabel('Date')
plt.ylabel('Interest')
plt.title(f'Google Trends Data for "{keyword}"')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Plot the data
plt.figure(figsize=(12, 6))
plt.plot(data.index, data[keyword], label=f'Interest Over Time for "{keyword}"')
plt.xlabel('Date')
plt.ylabel('Interest')
plt.title(f'Google Trends Data for "{keyword}"')
plt.legend()
plt.grid(True)
plt.show()
